# %% [markdown]
# <a href="https://colab.research.google.com/github/alexk2206/tds_capstone/blob/Alex-DEV/test_qa_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate Q and A test dataset
# I order to test a trained and evaluated model a test dataset is needed. This will be generated from scratch with new questions.

# %%
import pandas as pd
import random
import json
from itertools import chain, combinations
from datetime import datetime, timedelta

import google.generativeai as genai
from IPython.display import display, Markdown
from google.colab import userdata
import time

# %%
dfs = []

for i in range(1, 6):
    url = f'https://raw.githubusercontent.com/alexk2206/tds_capstone/refs/heads/main/questionnaires/questionnaire{i}.json'
    df = pd.read_json(url)
    df['options'] = df['options'].apply(lambda x: ', '.join([opt['option'] for opt in x]))
    dfs.append(df)

all_questions = pd.concat(dfs, ignore_index=True)

# %%
print(f"all_questions shape: {all_questions.shape}")
all_questions
# Out:
# all_questions shape: (25, 4)
#                                       id           type  \
# 0   aa2d8cdd-0758-4035-b0b6-ca18e2f380d8  SINGLE_SELECT
# 1   12e1ed1d-edaa-4e93-8645-de3850e998f9  SINGLE_SELECT
# 2   625012ae-9192-4cf6-a73d-55e1813d6014   MULTI_SELECT
# 3   0699fc5a-34a4-4160-bda1-fb135a3615da   MULTI_SELECT
# 4   815dab84-bc5e-4764-9777-0c0126e3173e   MULTI_SELECT
# 5   3f34e5b3-1cb0-48ea-93d2-3f21b3371b5d  SINGLE_SELECT
# 6   ba042f33-697e-4c6f-924c-b4de2c30f443  SINGLE_SELECT
# 7   7a776cc0-ffe8-4891-b8a9-dd5ff984de13   MULTI_SELECT
# 8   a0148bc7-15b3-41d5-b97c-6420b8bd927c           TEXT
# 9   5aefc81d-c5d2-41fc-bc7b-6117d1c7671e  SINGLE_SELECT
# 10  034b7b45-2139-4b5f-8933-6b48dd732920  SINGLE_SELECT
# 11  56127ae3-c20b-4082-bfad-d6976bee7003           DATE
# 12  c1bc3fad-ff12-486c-9c71-e0bff2f2a2a9           TEXT
# 13  25f0cc40-a168-40f9-aef3-5d9956de4d11  SINGLE_SELECT
# 14  6fddae02-26b3-4f76-8387-e02d44b19198   MULTI_SELECT
# 15  68048ce3-a6fe-4cb1-adea-7125fa56d743   MULTI_SELECT
# 16  3dd27f03-db17-4608-8f99-158f5a7c7abf         NUMBER
# 17  fd61784d-c75b-4e93-ac5d-b8d5425e0844   MULTI_SELECT
# 18  6f32fe36-96db-498a-a853-4dccb99b49d4  SINGLE_SELECT
# 19  0407e2fa-e5d3-4464-a33e-210013621431  SINGLE_SELECT
# 20  47466ef3-68cf-4cfa-aa2f-7e395ad4590f  SINGLE_SELECT
# 21  7bb14352-80ce-4ebf-b81c-70e0755cc7e6  SINGLE_SELECT
# 22  e95e34ce-1758-4037-9474-99d0557a7a29   MULTI_SELECT
# 23  72f9264b-8228-4f14-8387-a4d49797cfa0   MULTI_SELECT
# 24  6c5535e3-7d9f-4b81-9b44-e3c1a571bc51  SINGLE_SELECT
#
#                                              question  \
# 0                             Data processing consent
# 1                                      Customer group
# 2                              Products interested in
# 3                   What kind of follow up is planned
# 4                            Who to copy in follow up
# 5   Would you like to receive marketing informatio...
# 6                 What industry are you operating in?
# 7                What products are you interested in?
# 8                                               Notes
# 9                         What type of company is it?
# 10                  What is the size of your company?
# 11           When do you wish to receive a follow-up?
# 12                              Any additional notes?
# 13       Which language is wanted for communication?
# 14                       What is the type of contact?
# 15          What is the contact person interested in?
# 16          What phone number can we use for contact?
# 17  When does the contact person wish to receive a...
# 18                                      Customer type
# 19                              Customer satisfaction
# 20           Size of the trade fair team (on average)
# 21                                         CRM-System
# 22                                   Productinterests
# 23                            Searches a solution for
# 24                                         Next steps
#
#                                               options
# 0                                             Yes, No
# 1   End User, Wholesaler, Distributor, Consultant,...
# 2   MY-SYSTEM, Notion, JTS, JS EcoLine, AKW100, AX100
# 3           Email, Phone, Schedule a Visit, No action
# 4   Stephan Maier, Joachim Wagner, Erik Schneider,...
# 5                                             Yes, No
# 6   Aerospace, Computers & Networks, Government, M...
# 7   Automotive radar target simulation, Noise figu...
# 8   Please provide any additional information that...
# 9   Construction company, Craft enterprises, Scaff...
# 10    1-10, 11-50, 51-200, 201-2000, larger than 2000
# 11                                               Date
# 12  What additional information would you like to ...
# 13       German, Italian, Japanese , English, Spanish
# 14  Existing customer, Supplier, New customer / Pr...
# 15  100 Additive Manufacturing, 200 Automation, 30...
# 16                                       phone number
# 17                           1 week, 2 weeks, 3 weeks
# 18  New customer, Existing customer, Partner, Appl...
# 19  Very satisfied, Satisfied, Unsatisfied, Very u...
# 20  1-5, 6-10, 11-15, 16-20, 21-30, 31-40, more th...
# 21  Salesforce, Pipedrive, Close.io, Microsoft Dyn...
# 22  BusinessCards, DataEnrichment, VisitReport, Da...
# 23  Scan business cards, Clean up CRM, Extract dat...
# 24                               Offer, Meeting, Call

# %% [markdown]
# # Setting up a prompt for Chat GPT
# To create new questions for a test dataset we ask Chat GPT to generate them. The prompt we used looks like this:

# %% [markdown]
# You are a salesman at a trade fair and want to ask customers who visit your exhibition stand questions. You will be given a list of questions, the question types, and possible options to answer each question. I want you to think of completely new questions, their types, and possible answer options. Your aim is to create 20 questions with each type at least once for a new questionnaire for the next trade fair. Keep it short, as you are allowed to use only up to 32 tokens per question and up to 32 tokens for their options. It is important to come up with completely new questions!
#
# Sample questions divided by // : {questions}
#
# Question type divided by // : {type}
#
# Possible answer options per question divided by // : {options}
#
# New questions with type and answer options formatted as a json:

# %% [markdown]
# ## For {questions} we used this string:
#
# Data processing consent // Customer group // Products interested in // What kind of follow up is planned // Who to copy in follow up // Would you like to receive marketing information from via e-mail? // What industry are you operating in? // What products are you interested in? // Notes // What type of company is it? // What is the size of your company? // When do you wish to receive a follow-up? // Any additional notes? // Which language is wanted for communication? // What is the type of contact? // What is the contact person interested in? // What phone number can we use for contact? // When does the contact person wish to receive a follow up? // Customer type // Customer satisfaction // Size of the trade fair team (on average) // CRM-System // Productinterests // Searches a solution for // Next steps

# %% [markdown]
# ## For {type} we used this string:
#
# SINGLE_SELECT // SINGLE_SELECT // MULTI_SELECT // MULTI_SELECT // MULTI_SELECT // SINGLE_SELECT // SINGLE_SELECT // MULTI_SELECT // TEXT // SINGLE_SELECT // SINGLE_SELECT // DATE // TEXT // SINGLE_SELECT // MULTI_SELECT // MULTI_SELECT // NUMBER // MULTI_SELECT // SINGLE_SELECT // SINGLE_SELECT // SINGLE_SELECT // SINGLE_SELECT // MULTI_SELECT // MULTI_SELECT // SINGLE_SELECT

# %% [markdown]
# ## For {options} we used this string:
#
# Yes, No // End User, Wholesaler, Distributor, Consultant, Planner, Architect, R&D // MY-SYSTEM, Notion, JTS, JS EcoLine, AKW100, AX100 // Email, Phone, Schedule a Visit, No action // Stephan Maier, Joachim Wagner, Erik Schneider, Oliver Eibel, Angelina Haug, Marisa Peng, Johannes Wagner, Jessica Hanke, Sandro Kalter, Jens Roschmann, Domiki Stein, Sean Kennin, Tim Persson // Yes, No // Aerospace, Computers & Networks, Government, Medical, Automotive, Defense, Industrial, Network Operators & Infrastructure, Public Safety / Law Enforcement, Physical Security // Automotive radar target simulation, Noise figure measurements, Double-Pulse Testing, Display port debugging and compliance, High-speed interconnect testing // Please provide any additional information that you would like to share. // Construction company, Craft enterprises, Scaffolding company, Trading company, Production company, Education sector // 1-10, 11-50, 51-200, 201-2000, larger than 2000 // Date // What additional information would you like to share? // German, Italian, Japanese, English, Spanish // Existing customer, Supplier, New customer / Prospect, Press / media, Competitor // 100 Additive Manufacturing, 200 Automation, 300 Advanced Manufacturing, 234 Assembly Systems, 256 Joining Systems for large components, Others // phone number // 1 week, 2 weeks, 3 weeks // New customer, Existing customer, Partner, Applicant // Very satisfied, Satisfied, Unsatisfied, Very unsatisfied // 1-5, 6-10, 11-15, 16-20, 21-30, 31-40, more than 40 // Salesforce, Pipedrive, Close.io, Microsoft Dynamics, HubSpot, CAS, SAP Sales Cloud, Adito // BusinessCards, DataEnrichment, VisitReport, Data Cleansing, DataQuality // Scan business cards, Clean up CRM, Extract data from emails, Improve CRM data quality, Capture trade fair contacts // Offer, Meeting, Call

# %%
test_questions_url = 'https://raw.githubusercontent.com/alexk2206/tds_capstone/refs/heads/main/datasets/test_dataset_questions.json'
test_questions = pd.read_json(test_questions_url)
test_questions
# Out:
#                                              question           type  \
# 0        How did you hear about our exhibition stand?  SINGLE_SELECT
# 1       What is your primary goal at this trade fair?  SINGLE_SELECT
# 2    Which features are most important in a solution?   MULTI_SELECT
# 3    How would you prefer to receive product updates?  SINGLE_SELECT
# 4        Who in your company evaluates new solutions?   MULTI_SELECT
# 5   Do you plan to implement a solution within the...  SINGLE_SELECT
# 6         What is your preferred method of follow-up?  SINGLE_SELECT
# 7           What stage are you in the buying process?  SINGLE_SELECT
# 8   What challenges are you currently facing in yo...           TEXT
# 9               What department are you representing?  SINGLE_SELECT
# 10         How many employees does your company have?  SINGLE_SELECT
# 11      When do you expect to finalize your decision?           DATE
# 12   Do you have any specific technical requirements?           TEXT
# 13     What language do you prefer for communication?  SINGLE_SELECT
# 14  What type of customer relationship are you see...  SINGLE_SELECT
# 15  What technologies or solutions are you exploring?   MULTI_SELECT
# 16    What is your estimated budget for this project?         NUMBER
# 17           How soon are you looking for a solution?  SINGLE_SELECT
# 18  How satisfied are you with the current solutio...  SINGLE_SELECT
# 19  What support resources do you need for impleme...   MULTI_SELECT
#
#                                               options
# 0   Social media, Email invitation, Trade fair web...
# 1   Networking, Finding suppliers, Learning about ...
# 2   Ease of use, Cost efficiency, Scalability, Sec...
# 3   Email, Webinar, Newsletter, Social media, In-p...
# 4   Team leader, IT department, Procurement, CEO, ...
# 5                                             Yes, No
# 6   Phone call, Email, Video meeting, In-person vi...
# 7   Exploration, Evaluation, Decision-making, Alre...
# 8         Please share specific challenges or issues.
# 9      R&D, Procurement, Marketing, Operations, Other
# 10               1-10, 11-50, 51-200, 201-1000, 1000+
# 11                        Select an approximate date.
# 12                 Please describe your requirements.
# 13   English, German, French, Spanish, Italian, Other
# 14       Supplier, Partner, Reseller, End-user, Other
# 15  IoT, AI, Automation, Cloud computing, Cybersec...
# 16               Please provide an approximate value.
# 17  Immediately, 1-3 months, 4-6 months, Over 6 mo...
# 18  Very satisfied, Satisfied, Neutral, Unsatisfie...
# 19  Training, Documentation, Technical support, On...

# %%
def generate_combinations(options_list, max_size):
    return list(chain.from_iterable(combinations(options_list, r) for r in range(0, min(len(options_list), max_size) + 1)))


def generate_phone_number():
    phone_prefix = '01' + str(random.randint(100, 999)) + (str(random.randint(0, 9)) if random.random() < 0.5 else '')
    main_number = ''.join([str(random.randint(0, 9)) for _ in range(random.randint(6, 8))])
    phone_number = phone_prefix + main_number
    return [phone_number]


def generate_date(today=None):
    if today is None:
        today = datetime.today()

    random_days = random.randint(0, 13)
    random_date = today - timedelta(days=random_days)

    date = random_date.strftime('%Y-%m-%d')

    return [date]


def generate_notes():
    return ['Add additional information here']

# %%
def process_selections(row, max_size):
    question = row['question']
    options_list = row['options']
    question_type = row['type']
    expanded = []

    if question_type == 'MULTI_SELECT':
        options_combinations = generate_combinations(options_list, max_size=max_size)
        for combo in options_combinations:
            expanded.append({'question': question, 'type': question_type, 'options': options_list, 'intended_answer': list(combo)})

    elif question_type == 'SINGLE_SELECT':
        for option in options_list:
            expanded.append({'question': question, 'type': question_type, 'options': options_list, 'intended_answer': [option]})

    return expanded


def process_freetext(row):
    question = row['question']
    options_list = row['options']
    question_type = row['type']
    expanded = []

    if question_type == 'TEXT':
        expanded.append({'question': question, 'type': question_type, 'options': options_list, 'intended_answer': generate_notes()})

    elif question_type == 'NUMBER':
        expanded.append({'question': question, 'type': question_type, 'options': options_list, 'intended_answer': generate_phone_number()})

    elif question_type == 'DATE':
        expanded.append({'question': question, 'type': question_type, 'options': options_list, 'intended_answer': generate_date()})

    return expanded

# %%
min_q_amount = 8
max_q_amount = 12

def adjust_question_amount(df, column, random_state):
    random.seed(random_state)
    def adjust_group(group):
        max_amount = random.randint(min_q_amount, max_q_amount)

        if len(group) < max_amount:
            return group.sample(n=max_amount, replace=True, random_state=random_state)
        else:
            return group.sample(n=max_amount, random_state=random_state)

    return df.groupby(column, group_keys=False).apply(adjust_group).reset_index(drop=True)

# %%
selection_test_questions = test_questions[(test_questions['type'] == 'MULTI_SELECT') | (test_questions['type'] == 'SINGLE_SELECT')].reset_index(drop=True)
freetext_test_questions = test_questions[(test_questions['type'] != 'MULTI_SELECT') & (test_questions['type'] != 'SINGLE_SELECT')].reset_index(drop=True)

selection_counts = selection_test_questions['type'].value_counts()
freetext_counts = freetext_test_questions['type'].value_counts()

print(f'selection_test_questions shape: {selection_test_questions.shape}, counts per type:\n{selection_counts}')
print(f'freetext_test_questions shape: {freetext_test_questions.shape}, counts per type:\n{freetext_counts}')

print(selection_test_questions)
print(freetext_test_questions)
# Out:
# selection_test_questions shape: (16, 3), counts per type:
# type
# SINGLE_SELECT    12
# MULTI_SELECT      4
# Name: count, dtype: int64
# freetext_test_questions shape: (4, 3), counts per type:
# type
# TEXT      2
# DATE      1
# NUMBER    1
# Name: count, dtype: int64
#                                              question           type  \
# 0        How did you hear about our exhibition stand?  SINGLE_SELECT
# 1       What is your primary goal at this trade fair?  SINGLE_SELECT
# 2    Which features are most important in a solution?   MULTI_SELECT
# 3    How would you prefer to receive product updates?  SINGLE_SELECT
# 4        Who in your company evaluates new solutions?   MULTI_SELECT
# 5   Do you plan to implement a solution within the...  SINGLE_SELECT
# 6         What is your preferred method of follow-up?  SINGLE_SELECT
# 7           What stage are you in the buying process?  SINGLE_SELECT
# 8               What department are you representing?  SINGLE_SELECT
# 9          How many employees does your company have?  SINGLE_SELECT
# 10     What language do you prefer for communication?  SINGLE_SELECT
# 11  What type of customer relationship are you see...  SINGLE_SELECT
# 12  What technologies or solutions are you exploring?   MULTI_SELECT
# 13           How soon are you looking for a solution?  SINGLE_SELECT
# 14  How satisfied are you with the current solutio...  SINGLE_SELECT
# 15  What support resources do you need for impleme...   MULTI_SELECT
#
#                                               options
# 0   Social media, Email invitation, Trade fair web...
# 1   Networking, Finding suppliers, Learning about ...
# 2   Ease of use, Cost efficiency, Scalability, Sec...
# 3   Email, Webinar, Newsletter, Social media, In-p...
# 4   Team leader, IT department, Procurement, CEO, ...
# 5                                             Yes, No
# 6   Phone call, Email, Video meeting, In-person vi...
# 7   Exploration, Evaluation, Decision-making, Alre...
# 8      R&D, Procurement, Marketing, Operations, Other
# 9                1-10, 11-50, 51-200, 201-1000, 1000+
# 10   English, German, French, Spanish, Italian, Other
# 11       Supplier, Partner, Reseller, End-user, Other
# 12  IoT, AI, Automation, Cloud computing, Cybersec...
# 13  Immediately, 1-3 months, 4-6 months, Over 6 mo...
# 14  Very satisfied, Satisfied, Neutral, Unsatisfie...
# 15  Training, Documentation, Technical support, On...
#                                             question    type  \
# 0  What challenges are you currently facing in yo...    TEXT
# 1      When do you expect to finalize your decision?    DATE
# 2   Do you have any specific technical requirements?    TEXT
# 3    What is your estimated budget for this project?  NUMBER
#
#                                        options
# 0  Please share specific challenges or issues.
# 1                  Select an approximate date.
# 2           Please describe your requirements.
# 3         Please provide an approximate value.

# %%
selection_test_questions.loc[:, 'options'] = selection_test_questions['options'].str.split(', ').copy()
expanded_data = selection_test_questions.apply(lambda row: process_selections(row, max_size=6), axis=1).explode()
selection_test_intended_answers = pd.json_normalize(expanded_data)
print(f'selection_test_intended_answers shape: {selection_test_intended_answers.shape}')
selection_test_intended_answers.sample(25)
# Out:
# selection_test_intended_answers shape: (218, 4)
#                                               question           type  \
# 82         What is your preferred method of follow-up?  SINGLE_SELECT
# 43    How would you prefer to receive product updates?  SINGLE_SELECT
# 202  What support resources do you need for impleme...   MULTI_SELECT
# 174  What technologies or solutions are you exploring?   MULTI_SELECT
# 25    Which features are most important in a solution?   MULTI_SELECT
# 3         How did you hear about our exhibition stand?  SINGLE_SELECT
# 114  What technologies or solutions are you exploring?   MULTI_SELECT
# 179           How soon are you looking for a solution?  SINGLE_SELECT
# 22    Which features are most important in a solution?   MULTI_SELECT
# 2         How did you hear about our exhibition stand?  SINGLE_SELECT
# 60        Who in your company evaluates new solutions?   MULTI_SELECT
# 70        Who in your company evaluates new solutions?   MULTI_SELECT
# 59        Who in your company evaluates new solutions?   MULTI_SELECT
# 87           What stage are you in the buying process?  SINGLE_SELECT
# 203  What support resources do you need for impleme...   MULTI_SELECT
# 57        Who in your company evaluates new solutions?   MULTI_SELECT
# 89           What stage are you in the buying process?  SINGLE_SELECT
# 52        Who in your company evaluates new solutions?   MULTI_SELECT
# 90           What stage are you in the buying process?  SINGLE_SELECT
# 98          How many employees does your company have?  SINGLE_SELECT
# 131  What technologies or solutions are you exploring?   MULTI_SELECT
# 66        Who in your company evaluates new solutions?   MULTI_SELECT
# 164  What technologies or solutions are you exploring?   MULTI_SELECT
# 13    Which features are most important in a solution?   MULTI_SELECT
# 116  What technologies or solutions are you exploring?   MULTI_SELECT
#
#                                                options  \
# 82   [Phone call, Email, Video meeting, In-person v...
# 43   [Email, Webinar, Newsletter, Social media, In-...
# 202  [Training, Documentation, Technical support, O...
# 174  [IoT, AI, Automation, Cloud computing, Cyberse...
# 25   [Ease of use, Cost efficiency, Scalability, Se...
# 3    [Social media, Email invitation, Trade fair we...
# 114  [IoT, AI, Automation, Cloud computing, Cyberse...
# 179  [Immediately, 1-3 months, 4-6 months, Over 6 m...
# 22   [Ease of use, Cost efficiency, Scalability, Se...
# 2    [Social media, Email invitation, Trade fair we...
# 60   [Team leader, IT department, Procurement, CEO,...
# 70   [Team leader, IT department, Procurement, CEO,...
# 59   [Team leader, IT department, Procurement, CEO,...
# 87   [Exploration, Evaluation, Decision-making, Alr...
# 203  [Training, Documentation, Technical support, O...
# 57   [Team leader, IT department, Procurement, CEO,...
# 89   [Exploration, Evaluation, Decision-making, Alr...
# 52   [Team leader, IT department, Procurement, CEO,...
# 90   [Exploration, Evaluation, Decision-making, Alr...
# 98              [1-10, 11-50, 51-200, 201-1000, 1000+]
# 131  [IoT, AI, Automation, Cloud computing, Cyberse...
# 66   [Team leader, IT department, Procurement, CEO,...
# 164  [IoT, AI, Automation, Cloud computing, Cyberse...
# 13   [Ease of use, Cost efficiency, Scalability, Se...
# 116  [IoT, AI, Automation, Cloud computing, Cyberse...
#
#                                        intended_answer
# 82                                             [Email]
# 43                                           [Webinar]
# 202       [Training, Documentation, Technical support]
# 174  [AI, Automation, Cloud computing, Cybersecurit...
# 25                                 [Security, Support]
# 3                                      [Word of mouth]
# 114                                               [AI]
# 179                                    [Over 6 months]
# 22                          [Cost efficiency, Support]
# 2                                 [Trade fair website]
# 60                                  [Procurement, CEO]
# 70                 [IT department, Procurement, Other]
# 59                              [IT department, Other]
# 87                                        [Evaluation]
# 203       [Training, Documentation, Onsite assistance]
# 57                        [IT department, Procurement]
# 89                                   [Already decided]
# 52                                             [Other]
# 90                                        [Not buying]
# 98                                            [51-200]
# 131                   [Cloud computing, Cybersecurity]
# 66                     [Team leader, Procurement, CEO]
# 164   [AI, Automation, Cloud computing, Cybersecurity]
# 13                                       [Scalability]
# 116                                  [Cloud computing]

# %%
selection_test_intended_answers_scaled = adjust_question_amount(selection_test_intended_answers, 'question', 1)

selection_test_intended_answers_scaled_counts = selection_test_intended_answers_scaled['type'].value_counts()
print(f'freetext_test_questions_scaled shape: {selection_test_intended_answers_scaled.shape}\ncounts per type:\n{selection_test_intended_answers_scaled_counts}')
selection_test_intended_answers_scaled
# Out:
# freetext_test_questions_scaled shape: (161, 4)
# counts per type:
# type
# SINGLE_SELECT    119
# MULTI_SELECT      42
# Name: count, dtype: int64
# <ipython-input-40-552b170f2d03>:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(column, group_keys=False).apply(adjust_group).reset_index(drop=True)
#                                               question           type  \
# 0    Do you plan to implement a solution within the...  SINGLE_SELECT
# 1    Do you plan to implement a solution within the...  SINGLE_SELECT
# 2    Do you plan to implement a solution within the...  SINGLE_SELECT
# 3    Do you plan to implement a solution within the...  SINGLE_SELECT
# 4    Do you plan to implement a solution within the...  SINGLE_SELECT
# ..                                                 ...            ...
# 156       Who in your company evaluates new solutions?   MULTI_SELECT
# 157       Who in your company evaluates new solutions?   MULTI_SELECT
# 158       Who in your company evaluates new solutions?   MULTI_SELECT
# 159       Who in your company evaluates new solutions?   MULTI_SELECT
# 160       Who in your company evaluates new solutions?   MULTI_SELECT
#
#                                                options  \
# 0                                            [Yes, No]
# 1                                            [Yes, No]
# 2                                            [Yes, No]
# 3                                            [Yes, No]
# 4                                            [Yes, No]
# ..                                                 ...
# 156  [Team leader, IT department, Procurement, CEO,...
# 157  [Team leader, IT department, Procurement, CEO,...
# 158  [Team leader, IT department, Procurement, CEO,...
# 159  [Team leader, IT department, Procurement, CEO,...
# 160  [Team leader, IT department, Procurement, CEO,...
#
#                               intended_answer
# 0                                        [No]
# 1                                        [No]
# 2                                       [Yes]
# 3                                       [Yes]
# 4                                        [No]
# ..                                        ...
# 156  [Team leader, IT department, CEO, Other]
# 157           [Team leader, Procurement, CEO]
# 158                      [Procurement, Other]
# 159               [IT department, CEO, Other]
# 160              [IT department, Procurement]
#
# [161 rows x 4 columns]

# %%
freetext_test_questions_scaled = adjust_question_amount(freetext_test_questions, 'question', 1)

freetext_test_questions_scaled_counts = freetext_test_questions_scaled['type'].value_counts()
print(f'freetext_test_questions_scaled shape: {freetext_test_questions_scaled.shape}\ncounts per type:\n{freetext_test_questions_scaled_counts}')
freetext_test_questions_scaled
# Out:
# freetext_test_questions_scaled shape: (39, 3)
# counts per type:
# type
# TEXT      21
# DATE      10
# NUMBER     8
# Name: count, dtype: int64
# <ipython-input-40-552b170f2d03>:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(column, group_keys=False).apply(adjust_group).reset_index(drop=True)
#                                              question    type  \
# 0    Do you have any specific technical requirements?    TEXT
# 1    Do you have any specific technical requirements?    TEXT
# 2    Do you have any specific technical requirements?    TEXT
# 3    Do you have any specific technical requirements?    TEXT
# 4    Do you have any specific technical requirements?    TEXT
# 5    Do you have any specific technical requirements?    TEXT
# 6    Do you have any specific technical requirements?    TEXT
# 7    Do you have any specific technical requirements?    TEXT
# 8    Do you have any specific technical requirements?    TEXT
# 9   What challenges are you currently facing in yo...    TEXT
# 10  What challenges are you currently facing in yo...    TEXT
# 11  What challenges are you currently facing in yo...    TEXT
# 12  What challenges are you currently facing in yo...    TEXT
# 13  What challenges are you currently facing in yo...    TEXT
# 14  What challenges are you currently facing in yo...    TEXT
# 15  What challenges are you currently facing in yo...    TEXT
# 16  What challenges are you currently facing in yo...    TEXT
# 17  What challenges are you currently facing in yo...    TEXT
# 18  What challenges are you currently facing in yo...    TEXT
# 19  What challenges are you currently facing in yo...    TEXT
# 20  What challenges are you currently facing in yo...    TEXT
# 21    What is your estimated budget for this project?  NUMBER
# 22    What is your estimated budget for this project?  NUMBER
# 23    What is your estimated budget for this project?  NUMBER
# 24    What is your estimated budget for this project?  NUMBER
# 25    What is your estimated budget for this project?  NUMBER
# 26    What is your estimated budget for this project?  NUMBER
# 27    What is your estimated budget for this project?  NUMBER
# 28    What is your estimated budget for this project?  NUMBER
# 29      When do you expect to finalize your decision?    DATE
# 30      When do you expect to finalize your decision?    DATE
# 31      When do you expect to finalize your decision?    DATE
# 32      When do you expect to finalize your decision?    DATE
# 33      When do you expect to finalize your decision?    DATE
# 34      When do you expect to finalize your decision?    DATE
# 35      When do you expect to finalize your decision?    DATE
# 36      When do you expect to finalize your decision?    DATE
# 37      When do you expect to finalize your decision?    DATE
# 38      When do you expect to finalize your decision?    DATE
#
#                                         options
# 0            Please describe your requirements.
# 1            Please describe your requirements.
# 2            Please describe your requirements.
# 3            Please describe your requirements.
# 4            Please describe your requirements.
# 5            Please describe your requirements.
# 6            Please describe your requirements.
# 7            Please describe your requirements.
# 8            Please describe your requirements.
# 9   Please share specific challenges or issues.
# 10  Please share specific challenges or issues.
# 11  Please share specific challenges or issues.
# 12  Please share specific challenges or issues.
# 13  Please share specific challenges or issues.
# 14  Please share specific challenges or issues.
# 15  Please share specific challenges or issues.
# 16  Please share specific challenges or issues.
# 17  Please share specific challenges or issues.
# 18  Please share specific challenges or issues.
# 19  Please share specific challenges or issues.
# 20  Please share specific challenges or issues.
# 21         Please provide an approximate value.
# 22         Please provide an approximate value.
# 23         Please provide an approximate value.
# 24         Please provide an approximate value.
# 25         Please provide an approximate value.
# 26         Please provide an approximate value.
# 27         Please provide an approximate value.
# 28         Please provide an approximate value.
# 29                  Select an approximate date.
# 30                  Select an approximate date.
# 31                  Select an approximate date.
# 32                  Select an approximate date.
# 33                  Select an approximate date.
# 34                  Select an approximate date.
# 35                  Select an approximate date.
# 36                  Select an approximate date.
# 37                  Select an approximate date.
# 38                  Select an approximate date.

# %%
combined_test_df = pd.concat([selection_test_intended_answers_scaled, freetext_test_questions_scaled], ignore_index=True)

test_qa_dataset = combined_test_df.sample(frac=1, random_state=1).reset_index(drop=True)

print(f'test_qa_dataset shape: {test_qa_dataset.shape}')
test_qa_dataset.head(30)
# Out:
# test_qa_dataset shape: (200, 4)
#                                              question           type  \
# 0               What department are you representing?  SINGLE_SELECT
# 1            How soon are you looking for a solution?  SINGLE_SELECT
# 2   How satisfied are you with the current solutio...  SINGLE_SELECT
# 3           What stage are you in the buying process?  SINGLE_SELECT
# 4     What is your estimated budget for this project?         NUMBER
# 5       When do you expect to finalize your decision?           DATE
# 6      What language do you prefer for communication?  SINGLE_SELECT
# 7   Do you plan to implement a solution within the...  SINGLE_SELECT
# 8   How satisfied are you with the current solutio...  SINGLE_SELECT
# 9    Do you have any specific technical requirements?           TEXT
# 10  What challenges are you currently facing in yo...           TEXT
# 11       How did you hear about our exhibition stand?  SINGLE_SELECT
# 12       How did you hear about our exhibition stand?  SINGLE_SELECT
# 13      What is your primary goal at this trade fair?  SINGLE_SELECT
# 14  What support resources do you need for impleme...   MULTI_SELECT
# 15  What support resources do you need for impleme...   MULTI_SELECT
# 16       Who in your company evaluates new solutions?   MULTI_SELECT
# 17  How satisfied are you with the current solutio...  SINGLE_SELECT
# 18  What type of customer relationship are you see...  SINGLE_SELECT
# 19              What department are you representing?  SINGLE_SELECT
# 20   How would you prefer to receive product updates?  SINGLE_SELECT
# 21       How did you hear about our exhibition stand?  SINGLE_SELECT
# 22           How soon are you looking for a solution?  SINGLE_SELECT
# 23     What language do you prefer for communication?  SINGLE_SELECT
# 24  How satisfied are you with the current solutio...  SINGLE_SELECT
# 25   Do you have any specific technical requirements?           TEXT
# 26  How satisfied are you with the current solutio...  SINGLE_SELECT
# 27         How many employees does your company have?  SINGLE_SELECT
# 28      When do you expect to finalize your decision?           DATE
# 29         How many employees does your company have?  SINGLE_SELECT
#
#                                               options  \
# 0    [R&D, Procurement, Marketing, Operations, Other]
# 1   [Immediately, 1-3 months, 4-6 months, Over 6 m...
# 2   [Very satisfied, Satisfied, Neutral, Unsatisfi...
# 3   [Exploration, Evaluation, Decision-making, Alr...
# 4                Please provide an approximate value.
# 5                         Select an approximate date.
# 6   [English, German, French, Spanish, Italian, Ot...
# 7                                           [Yes, No]
# 8   [Very satisfied, Satisfied, Neutral, Unsatisfi...
# 9                  Please describe your requirements.
# 10        Please share specific challenges or issues.
# 11  [Social media, Email invitation, Trade fair we...
# 12  [Social media, Email invitation, Trade fair we...
# 13  [Networking, Finding suppliers, Learning about...
# 14  [Training, Documentation, Technical support, O...
# 15  [Training, Documentation, Technical support, O...
# 16  [Team leader, IT department, Procurement, CEO,...
# 17  [Very satisfied, Satisfied, Neutral, Unsatisfi...
# 18     [Supplier, Partner, Reseller, End-user, Other]
# 19   [R&D, Procurement, Marketing, Operations, Other]
# 20  [Email, Webinar, Newsletter, Social media, In-...
# 21  [Social media, Email invitation, Trade fair we...
# 22  [Immediately, 1-3 months, 4-6 months, Over 6 m...
# 23  [English, German, French, Spanish, Italian, Ot...
# 24  [Very satisfied, Satisfied, Neutral, Unsatisfi...
# 25                 Please describe your requirements.
# 26  [Very satisfied, Satisfied, Neutral, Unsatisfi...
# 27             [1-10, 11-50, 51-200, 201-1000, 1000+]
# 28                        Select an approximate date.
# 29             [1-10, 11-50, 51-200, 201-1000, 1000+]
#
#                                       intended_answer
# 0                                        [Operations]
# 1                                          [Not sure]
# 2                                    [Very satisfied]
# 3                                       [Exploration]
# 4                                                 NaN
# 5                                                 NaN
# 6                                            [German]
# 7                                                [No]
# 8                                       [Unsatisfied]
# 9                                                 NaN
# 10                                                NaN
# 11                                            [Other]
# 12                                     [Social media]
# 13                                            [Other]
# 14  [Documentation, Technical support, Onsite assi...
# 15           [Documentation, Onsite assistance, None]
# 16                        [IT department, CEO, Other]
# 17                                   [Very satisfied]
# 18                                            [Other]
# 19                                            [Other]
# 20                                     [Social media]
# 21                                 [Email invitation]
# 22                                      [Immediately]
# 23                                          [English]
# 24                                   [Very satisfied]
# 25                                                NaN
# 26                                 [Very unsatisfied]
# 27                                            [11-50]
# 28                                                NaN
# 29                                             [1-10]

# %%
# question count
print(test_qa_dataset['question'].value_counts())
# Out:
# question
# How did you hear about our exhibition stand?                       12
# What challenges are you currently facing in your industry?         12
# Who in your company evaluates new solutions?                       12
# What is your preferred method of follow-up?                        11
# How would you prefer to receive product updates?                   11
# What type of customer relationship are you seeking?                11
# What support resources do you need for implementation?             11
# What is your primary goal at this trade fair?                      11
# What department are you representing?                              11
# Which features are most important in a solution?                   11
# When do you expect to finalize your decision?                      10
# How satisfied are you with the current solutions in your field?    10
# Do you have any specific technical requirements?                    9
# Do you plan to implement a solution within the next 6 months?       9
# What language do you prefer for communication?                      9
# How soon are you looking for a solution?                            8
# What is your estimated budget for this project?                     8
# What stage are you in the buying process?                           8
# How many employees does your company have?                          8
# What technologies or solutions are you exploring?                   8
# Name: count, dtype: int64

# %%
test_qa_dataset.to_json('test_qa_dataset.json', orient='records')

# %%
key = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=key)
model = genai.GenerativeModel("gemini-2.0-flash-exp")

# %%
max_output_tokens = 48

def generate_selection_answer_easy(question, intended_answer):
  prompt = f"""
  You are asked a question, and you need to provide a natural, conversational answer in the first person. Do not use special characters other than ',' and '.'.
  Act like you really do not know which options there are and the intended answer is your answer.
  When given a range, use a number between the two values.
  Be concise but clear, and avoid unnecessary elaboration. Use up to {max_output_tokens} tokens.
  Question: {question}\n
  Intended answer: {intended_answer}\n
  Answer as a sentence, mentioning and explaining all the provided options:
  """

  response = model.generate_content(
      contents = prompt,
      generation_config = genai.GenerationConfig(
          max_output_tokens=max_output_tokens,
          temperature=2)
    )

  answer = response.text.strip()

  time.sleep(6)

  return {"answer": answer, "difficulty": "easy"}

def generate_number_answer_easy(question, intended_answer):
  prompt = f"""
  You are being asked for contact information, and your response should be clear and concise, as if you're giving someone your phone number and how you can be reached in a conversation.
  Mention the provided phone number and ensure your response sounds natural and professional.
  Your answer should be in the first person, present tense, and only include the relevant details. Use up to {max_output_tokens} tokens.
  Question: {question}\n
  Intended answer: {intended_answer}\n
  Answer as a sentence, providing the phone number and any relevant details:
  """

  response = model.generate_content(
      contents = prompt,
      generation_config = genai.GenerationConfig(
          max_output_tokens=max_output_tokens,
          temperature=2)
    )

  answer = response.text.strip()
  time.sleep(6)

  return {"answer": answer, "difficulty": "easy"}


def generate_freetext_answer_easy(question, intended_answer):
  prompt = f"""
  You are being asked if you have any additional notes or information to share.
  Your response should sound natural, in the first person, and can be either brief or more detailed, depending on the situation.
  You can provide additional information but you don't have to and mention it clearly and politely.
  If there isn't anything else to add, express that in a conversational manner. Use up to {max_output_tokens} tokens.
  Question: {question}\n
  Intended answer: {intended_answer}
  Answer as a sentence, providing any additional information or politely stating that there's nothing else to add:
  """

  response = model.generate_content(
      contents = prompt,
      generation_config = genai.GenerationConfig(
          max_output_tokens=max_output_tokens,
          temperature=2)
    )

  answer = response.text.strip()
  time.sleep(6)

  return {"answer": answer, "difficulty": "easy"}


def generate_date_answer_easy(question, intended_answer):
  prompt = f"""
  You are asked a question about a specific date, and you need to provide a natural, conversational answer in the first person.
  Include the date from the intended answer in your response, phrasing it naturally as if you're suggesting a meeting.
  Be concise but clear, and use up to {max_output_tokens} tokens.
  Question: {question}\n
  Intended Answer: {intended_answer}\n
  Context: Provide a conversational response mentioning the date in a natural way:
  """

  response = model.generate_content(
      contents = prompt,
      generation_config = genai.GenerationConfig(
          max_output_tokens=max_output_tokens,
          temperature=2)
    )

  answer = response.text.strip()
  time.sleep(6)

  return {"answer": answer, "difficulty": "easy"}

# %%
cycle_count = 0

def generate_answer_for_row(row):
    global cycle_count
    cycle_count += 1
    print(f"Cycle: {cycle_count}")

    question = row['question']
    intended_answer = row['intended_answer']
    question_type = row['type']

    if question_type in ['SINGLE_SELECT', 'MULTI_SELECT']:
        return generate_selection_answer_easy(question, intended_answer)
    elif question_type == 'NUMBER':
        return generate_number_answer_easy(question, intended_answer)
    elif question_type == 'TEXT':
        return generate_freetext_answer_easy(question, intended_answer)
    elif question_type == 'DATE':
        return generate_date_answer_easy(question, intended_answer)
    else:
        return {"answer": "Unknown question type", "difficulty": "unknown"}

# %%
cycle_count = 0

# Sampling
sample_type = "NUMBER"
sample_size = 5
sample_question = "Size of the trade fair team (on average)"

test_qa_dataset_filtered = test_qa_dataset[test_qa_dataset['type'] == sample_type]
#test_qa_dataset_filtered = test_qa_dataset[test_qa_dataset['question'] == sample_question]
#test_qa_dataset_filtered = test_qa_dataset.copy()

sampled_questions = test_qa_dataset_filtered.sample(n=min(sample_size, len(test_qa_dataset_filtered))).reset_index(drop=True)

sampled_questions[['context', 'difficulty']] = sampled_questions.apply(lambda row: pd.Series(generate_answer_for_row(row)), axis=1)

sampled_questions
# Out:
# Cycle: 1
# Cycle: 2
# Cycle: 3
# Cycle: 4
# Cycle: 5
#                                           question    type  \
# 0  What is your estimated budget for this project?  NUMBER
# 1  What is your estimated budget for this project?  NUMBER
# 2  What is your estimated budget for this project?  NUMBER
# 3  What is your estimated budget for this project?  NUMBER
# 4  What is your estimated budget for this project?  NUMBER
#
#                                 options intended_answer  \
# 0  Please provide an approximate value.             NaN
# 1  Please provide an approximate value.             NaN
# 2  Please provide an approximate value.             NaN
# 3  Please provide an approximate value.             NaN
# 4  Please provide an approximate value.             NaN
#
#                                              context difficulty
# 0  I can't give you a budget right now, but my ph...       easy
# 1  My phone number is 555-123-4567 if you'd like ...       easy
# 2  You can reach me at 555-123-4567. I'm currentl...       easy
# 3  My phone number is 555-123-4567, and I can be ...       easy
# 4  I don't have a budget for this project, but yo...       easy
