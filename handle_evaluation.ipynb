# %% [markdown]
# <a href="https://colab.research.google.com/github/alexk2206/tds_capstone/blob/Alex-DEV/handle_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
import ast

# Data in JSON format
data = [
    {
        "question": "Data consent?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "Yes",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "How to stay in contact?",
        "type": "MULTI_SELECT",
        "intended_answer": "[Email, Phone]",
        "predicted_answer": "[Email, Phone]",
        "intended_answer_binary": "1,1,0",
        "predicted_answer_binary": "1,1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Product interest?",
        "type": "MULTI_SELECT",
        "intended_answer": "[Computer, Mouse]",
        "predicted_answer": "[Computer, Keyboard, Mouse]",
        "intended_answer_binary": "1,0,0,1",
        "predicted_answer_binary": "1,0,1,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Product interest?",
        "type": "MULTI_SELECT",
        "intended_answer": "[Computer, Mouse]",
        "predicted_answer": "[Computer, Keyboard, Mouse]",
        "intended_answer_binary": "1,0,0,1",
        "predicted_answer_binary": "1,1,1,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "When next meeting?",
        "type": "DATE",
        "intended_answer": "2025-01-26",
        "predicted_answer": "2025-01-26",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "When next meeting?",
        "type": "DATE",
        "intended_answer": "2025-01-27",
        "predicted_answer": "2025-01-26",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Phone number?",
        "type": "NUMBER",
        "intended_answer": "0123456789",
        "predicted_answer": "0123456789",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Additional notes?",
        "type": "TEXT",
        "intended_answer": "I like beer",
        "predicted_answer": "I like beer",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    }
]

df = pd.DataFrame(data)

df["intended_answer_binary"] = df["intended_answer_binary"].apply(lambda x: ast.literal_eval(f"[{x}]") if x else [])
df["predicted_answer_binary"] = df["predicted_answer_binary"].apply(lambda x: ast.literal_eval(f"[{x}]") if x else [])

df
# Out:
#                   question           type    intended_answer  \
# 0            Data consent?  SINGLE_SELECT                Yes
# 1  How to stay in contact?   MULTI_SELECT     [Email, Phone]
# 2        Product interest?   MULTI_SELECT  [Computer, Mouse]
# 3        Product interest?   MULTI_SELECT  [Computer, Mouse]
# 4       When next meeting?           DATE         2025-01-26
# 5       When next meeting?           DATE         2025-01-27
# 6            Phone number?         NUMBER         0123456789
# 7        Additional notes?           TEXT        I like beer
#
#               predicted_answer intended_answer_binary predicted_answer_binary  \
# 0                          Yes                 [1, 0]                  [1, 0]
# 1               [Email, Phone]              [1, 1, 0]               [1, 1, 0]
# 2  [Computer, Keyboard, Mouse]           [1, 0, 0, 1]            [1, 0, 1, 1]
# 3  [Computer, Keyboard, Mouse]           [1, 0, 0, 1]            [1, 1, 1, 1]
# ...

# %%
data2 = [
    {
        "question": "Data consent?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "No",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "How to stay in contact?",
        "type": "MULTI_SELECT",
        "intended_answer": "[Email, Phone]",
        "predicted_answer": "[Email, Phone]",
        "intended_answer_binary": "1,1,0",
        "predicted_answer_binary": "1,1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Product interest?",
        "type": "MULTI_SELECT",
        "intended_answer": "[Computer, Mouse]",
        "predicted_answer": "[Computer, Keyboard, Mouse]",
        "intended_answer_binary": "1,0,0,1",
        "predicted_answer_binary": "1,0,1,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Product interest?",
        "type": "MULTI_SELECT",
        "intended_answer": "[Computer, Mouse]",
        "predicted_answer": "[Computer, Keyboard, Mouse]",
        "intended_answer_binary": "1,0,0,1",
        "predicted_answer_binary": "1,1,1,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "When next meeting?",
        "type": "DATE",
        "intended_answer": "2025-01-26",
        "predicted_answer": "2025-01-26",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "When next meeting?",
        "type": "DATE",
        "intended_answer": "2025-01-27",
        "predicted_answer": "2025-01-26",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Phone number?",
        "type": "NUMBER",
        "intended_answer": "0123456789",
        "predicted_answer": "0123456789",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Additional notes?",
        "type": "TEXT",
        "intended_answer": "I like beer",
        "predicted_answer": "I like beer",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Favorite color?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Blue",
        "predicted_answer": "Blue",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "How did you hear about us?",
        "type": "MULTI_SELECT",
        "intended_answer": "[Social Media, Word of Mouth]",
        "predicted_answer": "[Social Media, Email]",
        "intended_answer_binary": "1,1,0",
        "predicted_answer_binary": "1,0,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Preferred payment method?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Credit Card",
        "predicted_answer": "Debit Card",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "0,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Have you used our product before?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "No",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "0,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "What is your age?",
        "type": "NUMBER",
        "intended_answer": "30",
        "predicted_answer": "32",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Are you satisfied with our service?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "Yes",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "How often do you use our service?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Daily",
        "predicted_answer": "Weekly",
        "intended_answer_binary": "1,0,0",
        "predicted_answer_binary": "0,1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "What is your occupation?",
        "type": "TEXT",
        "intended_answer": "Software Developer",
        "predicted_answer": "Data Scientist",
        "intended_answer_binary": "",
        "predicted_answer_binary": "",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Are you interested in our premium plan?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "No",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "0,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "How would you rate our customer support?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Excellent",
        "predicted_answer": "Good",
        "intended_answer_binary": "1,0,0",
        "predicted_answer_binary": "0,1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Do you recommend our service?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "Yes",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Do you use mobile apps frequently?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "Yes",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "1,0",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Preferred language for communication?",
        "type": "SINGLE_SELECT",
        "intended_answer": "English",
        "predicted_answer": "Spanish",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "0,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Do you have any dietary restrictions?",
        "type": "SINGLE_SELECT",
        "intended_answer": "No",
        "predicted_answer": "Yes",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "0,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Would you like to receive newsletters?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "No",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "0,1",
        "model_name": "bert_based_cased"
    },
    {
        "question": "Would you like to attend webinars?",
        "type": "SINGLE_SELECT",
        "intended_answer": "Yes",
        "predicted_answer": "Yes",
        "intended_answer_binary": "1,0",
        "predicted_answer_binary": "1,0",
        "model_name": "bert_based_cased"
    }
]

df2 = pd.DataFrame(data2)

df2["intended_answer_binary"] = df2["intended_answer_binary"].apply(lambda x: ast.literal_eval(f"[{x}]") if x else [])
df2["predicted_answer_binary"] = df2["predicted_answer_binary"].apply(lambda x: ast.literal_eval(f"[{x}]") if x else [])

df2
# Out:
#                                     question           type  \
# 0                              Data consent?  SINGLE_SELECT
# 1                    How to stay in contact?   MULTI_SELECT
# 2                          Product interest?   MULTI_SELECT
# 3                          Product interest?   MULTI_SELECT
# 4                         When next meeting?           DATE
# 5                         When next meeting?           DATE
# 6                              Phone number?         NUMBER
# 7                          Additional notes?           TEXT
# 8                            Favorite color?  SINGLE_SELECT
# 9                 How did you hear about us?   MULTI_SELECT
# 10                 Preferred payment method?  SINGLE_SELECT
# 11         Have you used our product before?  SINGLE_SELECT
# 12                         What is your age?         NUMBER
# 13       Are you satisfied with our service?  SINGLE_SELECT
# 14         How often do you use our service?  SINGLE_SELECT
# ...

# %%
# Out:
#                   question           type                   intended_answer  \
# 0            Data consent?  SINGLE_SELECT                               Yes
# 1  How to stay in contact?   MULTI_SELECT                    [Email, Phone]
# 2        Product interest?   MULTI_SELECT                 [Computer, Mouse]
# 3       When next meeting?           DATE  We can meet on January 27th 2025
# 4            Phone number?         NUMBER    You can reach me at 0123456789
# 5        Additional notes?           TEXT                       I like beer
#
#               predicted_answer intended_answer_binary predicted_answer_binary  \
# 0                          Yes                 [1, 0]                  [1, 0]
# 1               [Email, Phone]              [1, 1, 0]               [1, 1, 0]
# 2  [Computer, Keyboard, Mouse]           [1, 0, 0, 1]            [1, 0, 1, 1]
# 3                   2025-01-26                     []                      []
# ...

# %%
# import pandas as pd
# import evaluate

# # Assume df is your DataFrame with the following columns:
# # "question", "type", "intended_answer", "predicted_answer",
# # "intended_answer_binary", "predicted_answer_binary", "model_name"

# # Load the F1 metric from evaluate (for MULTI_SELECT questions)
# f1_metric = evaluate.load("f1")

# # List to store the computed metric (as a dict) for each row.
# row_metrics = []

# # Iterate over each row in the DataFrame.
# for idx, row in df.iterrows():
#     metric_entry = {}

#     if row["type"] == "MULTI_SELECT":
#         # For MULTI_SELECT, the binary columns are already lists.
#         intended = row["intended_answer_binary"]   # e.g., [1, 1, 0]
#         predicted = row["predicted_answer_binary"]   # e.g., [1, 1, 0]

#         # Compute the F1 score.
#         # Pass the lists directly (do NOT wrap them in an extra list)
#         # and specify an averaging method (e.g., "macro").
#         result = f1_metric.compute(predictions=predicted,
#                                    references=intended,
#                                    average="macro")
#         score = result["f1"]
#         # Save both the metric used and the computed score.
#         metric_entry = {"metric": "f1", "score": score}

#     elif row["type"] in ["SINGLE_SELECT", "DATE", "NUMBER"]:
#         # For these types, use an exact match for "accuracy".
#         intended = row["intended_answer"]
#         predicted = row["predicted_answer"]
#         score = 1.0 if predicted == intended else 0.0
#         metric_entry = {"metric": "accuracy", "score": score}

#     elif row["type"] == "TEXT":
#         # For TEXT questions, no metric is computed.
#         metric_entry = {"metric": None, "score": None}

#     else:
#         # For any other type, default to None.
#         metric_entry = {"metric": None, "score": None}

#     # Append the dictionary for this row.
#     row_metrics.append(metric_entry)

# # Add a new column 'metrics' to the DataFrame containing the computed metric dictionary for each row.
# df['metrics'] = row_metrics

# # Display the DataFrame with the new 'metrics' column.
# print(df[['question', 'type', 'metrics']])
# df
# Out:
#                   question           type  \
# 0            Data consent?  SINGLE_SELECT
# 1  How to stay in contact?   MULTI_SELECT
# 2        Product interest?   MULTI_SELECT
# 3       When next meeting?           DATE
# 4            Phone number?         NUMBER
# 5        Additional notes?           TEXT
#
#                                          metrics
# 0           {'metric': 'accuracy', 'score': 1.0}
# 1                 {'metric': 'f1', 'score': 1.0}
# 2  {'metric': 'f1', 'score': 0.7333333333333334}
# 3           {'metric': 'accuracy', 'score': 0.0}
# 4           {'metric': 'accuracy', 'score': 1.0}
# 5                {'metric': None, 'score': None}
#                   question           type    intended_answer  \
# 0            Data consent?  SINGLE_SELECT                Yes
# 1  How to stay in contact?   MULTI_SELECT     [Email, Phone]
# 2        Product interest?   MULTI_SELECT  [Computer, Mouse]
# 3       When next meeting?           DATE         2025-01-27
# ...

# %%
#!pip install evaluate
import pandas as pd
import evaluate

# Create empty lists to accumulate predictions and references for each metric type
multi_select_preds = []
multi_select_refs = []

single_select_preds = []  # for SINGLE_SELECT
single_select_refs = []

date_preds = []  # for DATE
date_refs = []

number_preds = []  # for NUMBER
number_refs = []

# Iterate over the DataFrame and accumulate data by type
for _, row in df2.iterrows():
    if row["type"] == "MULTI_SELECT":
        # For MULTI_SELECT, the binary columns are already lists (e.g., [1, 1, 0])
        multi_select_preds.extend(row["predicted_answer_binary"])  # Flatten the list
        multi_select_refs.extend(row["intended_answer_binary"])   # Flatten the list

    elif row["type"] == "SINGLE_SELECT":
        # For SINGLE_SELECT, compute exact match accuracy
        correct = 1 if row["predicted_answer"] == row["intended_answer"] else 0
        single_select_preds.append(correct)
        single_select_refs.append(1)  # Reference is 1 for each example (expected correct)

    elif row["type"] == "DATE":
        # For DATE, compute exact match accuracy
        correct = 1 if row["predicted_answer"] == row["intended_answer"] else 0
        date_preds.append(correct)
        date_refs.append(1)  # Reference is 1 for each example (expected correct)

    elif row["type"] == "NUMBER":
        # For NUMBER, compute exact match accuracy
        correct = 1 if row["predicted_answer"] == row["intended_answer"] else 0
        number_preds.append(correct)
        number_refs.append(1)  # Reference is 1 for each example (expected correct)

    # TEXT type is ignored, no need to accumulate for TEXT questions

# Now compute the overall metrics:

# MULTI_SELECT using F1
f1_metric = evaluate.load("f1")
f1_metric.add_batch(predictions=multi_select_preds, references=multi_select_refs)
multi_select_result = f1_metric.compute(average="macro")
print("Overall MULTI_SELECT F1 score:", multi_select_result["f1"])

# SINGLE_SELECT using Accuracy
accuracy_metric = evaluate.load("accuracy")
accuracy_metric.add_batch(predictions=single_select_preds, references=single_select_refs)
single_select_result = accuracy_metric.compute()
print("Overall SINGLE_SELECT Accuracy:", single_select_result["accuracy"])

# DATE using Accuracy
accuracy_metric.add_batch(predictions=date_preds, references=date_refs)
date_result = accuracy_metric.compute()
print("Overall DATE Accuracy:", date_result["accuracy"])

# NUMBER using Accuracy
accuracy_metric.add_batch(predictions=number_preds, references=number_refs)
number_result = accuracy_metric.compute()
print("Overall NUMBER Accuracy:", number_result["accuracy"])
# Out:
# Overall MULTI_SELECT F1 score: 0.5906432748538011
# Overall SINGLE_SELECT Accuracy: 0.35714285714285715
# Overall DATE Accuracy: 0.5
# Overall NUMBER Accuracy: 0.5

# %%
 0.42857142857142855
